# %% [markdown]
# <a href='http://moncoachdata.com'><img src= 'https://moncoachdata.com/wp-content/uploads/MonCoachData-cours/MonCoachData.jpg' width=400/></a>
#
#
# ---
#
#
# <center><em>Copyright MonCoachData (tous droits réservés)</em></center>
# <center><em>Pour plus d'informations, visitez notre site <a href='http://moncoachdata.com'>moncoachdata.com</a></em></center>
#
#
#
# ---

# %% [markdown]
# # Mise en place des concepts de Machine Learning
#
#
#
# *   Introduction au Machine Learning
# *   Pourquoi faire le Machine Learning ? Quel est son but ?
# *   Quels sont les différents types de Machine Learning ? (Supervisé versus Non Supervisé)
# *   Quels sont les principes et processus de l'apprentissage Supervisé ?

# %% [markdown]
# Section uniquement théorique, sans code, mais très utile pour poursuivre la MasterClass.
