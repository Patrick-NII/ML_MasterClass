# %% [markdown]
# <a href='http://moncoachdata.com'><img src= 'https://moncoachdata.com/wp-content/uploads/MonCoachData-cours/MonCoachData.jpg' width=400/></a>
#
#
# ---
#
#
# <center><em>Copyright MonCoachData (tous droits réservés)</em></center>
# <center><em>Pour plus d'informations, visitez notre site <a href='http://moncoachdata.com'>moncoachdata.com</a></em></center>
#
#
#
# ---

# %% [markdown]
# #  Diagrammes Matriciels - Matrix Plots
#
# **NOTE: N'oubliez pas de regarder la vidéo, car tous les jeux de données (datasets) ne sont pas adaptés à une carte thermique (heatmap) ou à une carte de cluster (clustermap).**

# %% [markdown]
# ## Importations

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Données
#
# World Population Prospects publie des estimations de la population des Nations Unies pour tous les pays du monde, chaque année de 1950 à 2020, ainsi que des projections pour différents scénarios (variances faible, moyenne et élevée) de 2020 à 2100. Les chiffres présentés ici correspondent aux projections de la variante moyenne pour l'année donnée.
#
# https://www.ined.fr/en/everything_about_population/data/all-countries/?lst_continent=900&lst_pays=926
#
# Source : Estimations pour l'année en cours basées sur les données du World Population Prospects. Nations Unies.

# %%
df = pd.read_csv()

# %%
# Projections 2020
df = pd.read_csv('country_table.csv')

# %%
df
# Out:
#                          Countries  ...  Growth rate
# 0                           AFRICA  ...        24.40
# 1                             ASIA  ...         8.44
# 2                           EUROPE  ...         0.38
# 3  LATIN AMERICA AND THE CARIBBEAN  ...         8.89
# 4                 NORTHERN AMERICA  ...         6.11
# 5                          OCEANIA  ...        12.79
# 6                            WORLD  ...        10.36
#
# [7 rows x 6 columns]

# %% [markdown]
# ## Heatmap

# %%
df = df.set_index('Countries')

# %%
df
# Out:
#                                  Birth rate  ...  Growth rate
# Countries                                    ...
# AFRICA                               32.577  ...        24.40
# ASIA                                 15.796  ...         8.44
# EUROPE                               10.118  ...         0.38
# LATIN AMERICA AND THE CARIBBEAN      15.886  ...         8.89
# NORTHERN AMERICA                     11.780  ...         6.11
# OCEANIA                              16.235  ...        12.79
# WORLD                                17.963  ...        10.36
#
# [7 rows x 5 columns]

# %%
# Indique clairement l'espérance de vie dans différentes unités
sns.heatmap(df);

# %%
rates = df.drop('Life expectancy',axis=1)

# %%
sns.heatmap(rates);

# %%
sns.heatmap(rates,linewidth=0.5);

# %%
sns.heatmap(rates,linewidth=0.5,annot=True);

# %%
# Notez que ce n'est pas l'argument palette ici
sns.heatmap(rates,linewidth=0.5,annot=True,cmap='viridis');

# %%
# Définir la barre de couleurs en fonction de la valeur du dataset
sns.heatmap(rates,linewidth=0.5,annot=True,cmap='viridis',center=40);

# %%
# Définir la barre de couleurs en fonction de la valeur du dataset
sns.heatmap(rates,linewidth=0.5,annot=True,cmap='viridis',center=1);

# %% [markdown]
# ## Clustermap
#
# Tracez une matrice de données sous la forme d'une heatmap hiérarchisée.

# %%
sns.clustermap(rates);

# %%
sns.clustermap(rates,col_cluster=False);

# %%
sns.clustermap(rates,col_cluster=False,figsize=(12,8),cbar_pos=(-0.1, .2, .03, .4));

# %%
rates.index.set_names('',inplace=True)

# %%
rates
# Out:
#                                  Birth rate  ...  Growth rate
#                                              ...
# AFRICA                               32.577  ...        24.40
# ASIA                                 15.796  ...         8.44
# EUROPE                               10.118  ...         0.38
# LATIN AMERICA AND THE CARIBBEAN      15.886  ...         8.89
# NORTHERN AMERICA                     11.780  ...         6.11
# OCEANIA                              16.235  ...        12.79
# WORLD                                17.963  ...        10.36
#
# [7 rows x 4 columns]

# %%
# Rappelez-vous que vous pouvez toujours modifier le dataframe avant de passer à Seaborn.
sns.clustermap(rates,col_cluster=False,figsize=(12,8),cbar_pos=(-0.1, .2, .03, .4));
